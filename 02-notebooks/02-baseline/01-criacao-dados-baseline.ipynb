# %% [markdown]
# # Explorações iniciais

# %% [markdown]
# ## 0. Setup

# %%
#---- Bibliotecas:

# Análise e manipulação de dados:

import pandas as pd
import numpy as np

# Visualização de dados:

import plotly.io as pio
import plotly.express as px

# %%
#---- Data path:

data_path = '../../03-data/'

#---- Template dos gráficos:

pio.templates.default = "plotly_white"

# %% [markdown]
# ## 1. Extração dos dados

# %% [markdown]
# ### 1.1. Dimensão de livros

# %%
books = pd.read_csv(data_path + '01-raw/Books.csv', low_memory = False)

books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %% [markdown]
# ### 1.2. Dimensão de Usuários

# %%
users = pd.read_csv(data_path + '01-raw/Users.csv', low_memory = False)

users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %% [markdown]
# ### 1.3. Fato de avaliações dos livros pelos usuários

# %%
ratings = pd.read_csv(data_path + '01-raw/Ratings.csv', low_memory = False)

ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %% [markdown]
# ## 2. Manuseio dos dados

# %% [markdown]
# ### 2.1. Abrindo a variável de Location

# %%
users[['city', 'state', 'country']] = users['Location'].str.split(pat = ',', n = 2, expand = True)

users.head()
# Out:
#    User-ID                            Location   Age         city  \
# 0        1                  nyc, new york, usa   NaN          nyc
# 1        2           stockton, california, usa  18.0     stockton
# 2        3     moscow, yukon territory, russia   NaN       moscow
# 3        4           porto, v.n.gaia, portugal  17.0        porto
# 4        5  farnborough, hants, united kingdom   NaN  farnborough
#
#               state          country
# 0          new york              usa
# 1        california              usa
# 2   yukon territory           russia
# 3          v.n.gaia         portugal
# 4             hants   united kingdom

# %% [markdown]
# ### 2.2. Join nos dados

# %%
df_ratings_user = ratings\
    .merge(books, on = 'ISBN', how = 'left')\
    .merge(users, on = 'User-ID', how = 'left')\
    .drop(columns = ['Location'] + [col for col in books.columns if 'URL' in col])

df_ratings_user.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6
#
#                                           Book-Title      Book-Author  \
# 0                               Flesh Tones: A Novel       M. J. Rose
# 1                                   Rites of Passage       Judith Rae
# 2                                       The Notebook  Nicholas Sparks
# 3                                     Help!: Level 1    Philip Prowse
# 4  The Amsterdam Connection : Level 4 (Cambridge ...      Sue Leather
#
#   Year-Of-Publication                   Publisher   Age     city  \
# 0                2002            Ballantine Books   NaN    tyler
# 1                2001                      Heinle   NaN  seattle
# 2                1996                Warner Books  16.0        h
# 3                1999  Cambridge University Press  16.0   rijeka
# 4                2001  Cambridge University Press  16.0   rijeka
#
#               state     country
# 0             texas         usa
# 1        washington         usa
# 2   new south wales   australia
# 3               n/a     croatia
# 4               n/a     croatia

# %% [markdown]
# ### 2.3. Split em treino e teste
#
# **Regra:**
#
# - Filtra avaliações diferentes de 0
# - Filtrar usuários que tem 3 ou mais avaliações
# - Treino: Todas as avaliações do usuário, exceto a última
# - Teste: Última avaliação do usuário

# %%
#---- Filtrar avaliações diferentes de 0

df_ratings_user_filtered = df_ratings_user\
    .copy()\
    .query('`Book-Rating` != 0')

df_ratings_user_filtered.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 1   276726  0155061224            5
# 3   276729  052165615X            3
# 4   276729  0521795028            6
# 6   276736  3257224281            8
# 7   276737  0600570967            6
#
#                                           Book-Title    Book-Author  \
# 1                                   Rites of Passage     Judith Rae
# 3                                     Help!: Level 1  Philip Prowse
# 4  The Amsterdam Connection : Level 4 (Cambridge ...    Sue Leather
# 6                                                NaN            NaN
# 7                                                NaN            NaN
#
#   Year-Of-Publication                   Publisher   Age      city  \
# 1                2001                      Heinle   NaN   seattle
# 3                1999  Cambridge University Press  16.0    rijeka
# 4                2001  Cambridge University Press  16.0    rijeka
# 6                 NaN                         NaN   NaN  salzburg
# 7                 NaN                         NaN  14.0    sydney
#
#               state     country
# 1        washington         usa
# 3               n/a     croatia
# 4               n/a     croatia
# 6          salzburg     austria
# 7   new south wales   australia

# %%
#---- Filtrar usuários que tem 3 ou mais avaliações

# Criando a variável de RowNumber

df_ratings_user_filtered['RN'] = df_ratings_user_filtered\
    .groupby('User-ID')\
    .cumcount() + 1

# %%
# Separando os usuários que tem 3 ou mais avaliações diferentes de 0

users_3more_rating = df_ratings_user_filtered\
    .groupby('User-ID', as_index = False)['RN']\
    .max()\
    .query('RN >= 3')['User-ID']\
    .to_list()

# %%
# Filtrando os usuários acima:

df_ratings_user_filtered = df_ratings_user_filtered\
    .query(f'`User-ID`.isin({users_3more_rating})')

df_ratings_user_filtered.head()
# Out:
#     User-ID        ISBN  Book-Rating                         Book-Title  \
# 16   276747  0060517794            9           Little Altars Everywhere
# 19   276747  0671537458            9                  Waiting to Exhale
# 20   276747  0679776818            8  Birdsong: A Novel of Love and War
# 21   276747  0943066433            7  How to Deal With Difficult People
# 23   276747  1885408226            7      The Golden Rule of Schmoozing
#
#          Book-Author Year-Of-Publication                Publisher   Age  \
# 16     Rebecca Wells                2003              HarperTorch  25.0
# 19    Terry McMillan                1995                   Pocket  25.0
# 20  Sebastian Faulks                1997        Vintage Books USA  25.0
# 21     Rick Brinkman                1995         Careertrack Inc.  25.0
# 23          Aye Jaye                1998  Listen &amp; Live Audio  25.0
#
#          city  state country  RN
# 16  iowa city   iowa     usa   1
# 19  iowa city   iowa     usa   2
# 20  iowa city   iowa     usa   3
# 21  iowa city   iowa     usa   4
# 23  iowa city   iowa     usa   5

# %%
# Separando os dados de teste:

df_last_item_user_id = df_ratings_user_filtered\
    .groupby('User-ID', as_index = False)['RN']\
    .max()

df_test = df_ratings_user_filtered\
    .merge(df_last_item_user_id, on = ['User-ID', 'RN'], how = 'inner')

df_test
# Out:
#        User-ID         ISBN  Book-Rating  \
# 0       276747   1885408226            7
# 1       276762  N3453124715            4
# 2       276772   3596151465           10
# 3       276786   8478442588            6
# 4       276788   055310666X           10
# ...        ...          ...          ...
# 22563   276680   1931561648            9
# 22564   276681   1931333246           10
# 22565   276683   0553278231            9
# 22566   276688   1575660792            7
# 22567   276704   1563526298            9
#
#                                               Book-Title         Book-Author  \
# 0                          The Golden Rule of Schmoozing            Aye Jaye
# 1                                                    NaN                 NaN
# 2                                        Henry der Held.         Roddy Doyle
# 3                                 El Elogio de La Sombra            Tanazaki
# 4                                           False Memory      Dean R. Koontz
# ...                                                  ...                 ...
# 22563  The Time Traveler's Wife (Today Show Book Club...  Audrey Niffenegger
# 22564                                             Chorus        Kurt Messick
# 22565                                        Cannery Row      John Steinbeck
# 22566                                        Gray Matter     Shirley Kennett
# 22567  Get Clark Smart : The Ultimate Guide for the S...        Clark Howard
#
#       Year-Of-Publication                          Publisher   Age  \
# 0                    1998            Listen &amp; Live Audio  25.0
# 1                     NaN                                NaN  25.0
# 2                    2001           Fischer (Tb.), Frankfurt   NaN
# 3                    1998                            Siruela  34.0
# 4                    1999                       Bantam Books   NaN
# ...                   ...                                ...   ...
# 22563                2003            MacAdam/Cage Publishing  55.0
# 22564                2003                    Dry Bones Press  43.0
# 22565                1986                       Bantam Books   NaN
# 22566                1996  Kensington Publishing Corporation   NaN
# 22567                2000                   Longstreet Press   NaN
#
#                     city                 state   country  RN
# 0              iowa city                  iowa       usa   5
# 1               duisburg   nordrhein-westfalen   germany   4
# 2                   bonn   nordrhein-westfalen   germany   3
# 3                 madrid                madrid     spain   4
# 4                mentone            california       usa   3
# ...                  ...                   ...       ...  ..
# 22563  hopewell junction              new york       usa  91
# 22564            chicago              illinois       usa  11
# 22565          charlotte        north carolina       usa   3
# 22566           fort lee            new jersey       usa  29
# 22567         cedar park                 texas       usa   5
#
# [22568 rows x 12 columns]

# %%
#---- Dados de treino

df_train = df_ratings_user_filtered\
    .merge(df_last_item_user_id.assign(indicador = 1), on = ['User-ID', 'RN'], how = 'left')\
    .query('indicador.isna()')\
    .drop(columns = 'indicador')

df_train
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        276747  0060517794            9
# 1        276747  0671537458            9
# 2        276747  0679776818            8
# 3        276747  0943066433            7
# 5        276762  0380711524            5
# ...         ...         ...          ...
# 368572   276688  1551669315            6
# 368574   276704  0345386108            6
# 368575   276704  0380796155            5
# 368576   276704  0743211383            7
# 368577   276704  0806917695            5
#
#                                                Book-Title        Book-Author  \
# 0                                Little Altars Everywhere      Rebecca Wells
# 1                                       Waiting to Exhale     Terry McMillan
# 2                       Birdsong: A Novel of Love and War   Sebastian Faulks
# 3                       How to Deal With Difficult People      Rick Brinkman
# 5                                            See Jane Run       Joy Fielding
# ...                                                   ...                ...
# 368572                                     The Third Wife  Jasmine Cresswell
# 368574                                        Winter Moon     Dean R. Koontz
# 368575                                       White Abacus   Damien Broderick
# 368576                                       Dreamcatcher       Stephen King
# 368577  Perplexing Lateral Thinking Puzzles: Scholasti...        Paul Sloane
#
#        Year-Of-Publication            Publisher   Age        city  \
# 0                     2003          HarperTorch  25.0   iowa city
# 1                     1995               Pocket  25.0   iowa city
# 2                     1997    Vintage Books USA  25.0   iowa city
# 3                     1995     Careertrack Inc.  25.0   iowa city
# 5                     1992                 Avon  25.0    duisburg
# ...                    ...                  ...   ...         ...
# 368572                2002                 Mira   NaN    fort lee
# 368574                1995     Ballantine Books   NaN  cedar park
# 368575                1998                  Eos   NaN  cedar park
# 368576                2001             Scribner   NaN  cedar park
# 368577                1997  Sterling Publishing   NaN  cedar park
#
#                        state   country  RN
# 0                       iowa       usa   1
# 1                       iowa       usa   2
# 2                       iowa       usa   3
# 3                       iowa       usa   4
# 5        nordrhein-westfalen   germany   1
# ...                      ...       ...  ..
# 368572            new jersey       usa  28
# 368574                 texas       usa   1
# 368575                 texas       usa   2
# 368576                 texas       usa   3
# 368577                 texas       usa   4
#
# [346011 rows x 12 columns]

# %% [markdown]
# ### 2.4. Escolha dos top 5, 10 e 20 livros
#
# **Regras**:
#
# - Melhores avaliações (média)
# - Ter sido avaliado por 10 ou mais usuários

# %%
top20_books = df_ratings_user_filtered\
    .groupby('Book-Title', as_index = False)\
    .agg(
        media_rating = ('Book-Rating', 'mean'),
        frequencia = ('ISBN', 'count')
    )\
    .query('frequencia > 10')\
    .sort_values(by = 'media_rating', ascending = False)\
    .head(20)['Book-Title']\
    .to_list()

top20_books
# Out:
# ['Postmarked Yesteryear: 30 Rare Holiday Postcards',
#  'Dilbert: A Book of Postcards',
#  'Harry Potter and the Chamber of Secrets Postcard Book',
#  'Route 66 Postcards: Greetings from the Mother Road',
#  'Fox in Socks (I Can Read It All by Myself Beginner Books)',
#  'The Giving Tree',
#  'The Return of the King (The Lord of The Rings, Part 3)',
#  'The Authoritative Calvin and Hobbes (Calvin and Hobbes)',
#  "My Sister's Keeper : A Novel (Picoult, Jodi)",
#  'Where the Sidewalk Ends : Poems and Drawings',
#  'Calvin and Hobbes',
#  'Maus a Survivors Tale: My Father Bleeds History',
#  'Are You My Mother?',
#  '52 Deck Series: 52 Ways to Celebrate Friendship',
#  'Mrs. Mike',
#  "The Lion, the Witch and the Wardrobe (Full-Color Collector's Edition)",
#  "Oh, the Places You'll Go!",
#  'Die unendliche Geschichte: Von A bis Z',
#  'Complete Chronicles of Narnia',
#  "Scientific Progress Goes 'Boink':  A Calvin and Hobbes Collection"]

# %% [markdown]
# ## 3. Exportação dos dados

# %%
#---- Treino: 

df_train\
        .to_parquet(path = data_path + '02-processed/01-train_data.parquet', index = False)

# %%
#---- Teste: 

df_test\
        .to_parquet(path = data_path + '02-processed/01-test_data.parquet', index = False)

# %%
#---- Lista com os top20 livros

import pickle
with open(data_path + '02-processed/03-top20-books.pkl', 'wb') as fp:
    pickle.dump(top20_books, fp)
